# %% [markdown]
# <a href="https://colab.research.google.com/github/prachip4013-ctrl/PrachiPathak-/blob/main/chapter_appendix-tools-for-deep-learning/jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Asignment 5

#1.
String = input ("Enter a string :")
print("length of string is :" ,len(String))



#2.
s = input("Enter string:")
print(s[:2] + s[-2:])



#3.
a = input("First: ")
b = input("Second: ")
print(a + b)
# Out:
# Enter a string :Learning
# length of string is : 9
# Enter string:Computer
# Cor
# First: Open
# Second: Source
# Open Source
